# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Objectives" data-toc-modified-id="Objectives-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Objectives</a></span></li><li><span><a href="#What-is-Pandas?" data-toc-modified-id="What-is-Pandas?-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>What is Pandas?</a></span><ul class="toc-item"><li><span><a href="#Accessing-Data" data-toc-modified-id="Accessing-Data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Accessing Data</a></span></li><li><span><a href="#DataFrames-and-Series" data-toc-modified-id="DataFrames-and-Series-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>DataFrames and Series</a></span></li><li><span><a href="#More-Basic-DataFrame-Attributes-and-Methods" data-toc-modified-id="More-Basic-DataFrame-Attributes-and-Methods-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>More Basic DataFrame Attributes and Methods</a></span><ul class="toc-item"><li><span><a href="#.head()-:-first-5-rows" data-toc-modified-id=".head()-:-first-5-rows-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span><code>.head()</code> : first 5 rows</a></span></li><li><span><a href="#.tail()-:-last-5-rows" data-toc-modified-id=".tail()-:-last-5-rows-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span><code>.tail()</code> : last 5 rows</a></span></li><li><span><a href="#.info()-:-information-about-the-columns,-including-about-nulls-in-those-columns" data-toc-modified-id=".info()-:-information-about-the-columns,-including-about-nulls-in-those-columns-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span><code>.info()</code> : information about the columns, including about nulls in those columns</a></span></li><li><span><a href="#.describe()-:-statistics-about-the-data" data-toc-modified-id=".describe()-:-statistics-about-the-data-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span><code>.describe()</code> : statistics about the data</a></span></li><li><span><a href="#.dtypes-:-data-types-of-each-column" data-toc-modified-id=".dtypes-:-data-types-of-each-column-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span><code>.dtypes</code> : data types of each column</a></span></li><li><span><a href="#.shape-:-number-of-rows-and-columns" data-toc-modified-id=".shape-:-number-of-rows-and-columns-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span><code>.shape</code> : number of rows and columns</a></span></li><li><span><a href="#Statistics" data-toc-modified-id="Statistics-2.3.7"><span class="toc-item-num">2.3.7&nbsp;&nbsp;</span>Statistics</a></span></li></ul></li><li><span><a href="#Enough-With-The-Small-Stuff---Bring-On-Real-Data!" data-toc-modified-id="Enough-With-The-Small-Stuff---Bring-On-Real-Data!-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Enough With The Small Stuff - Bring On Real Data!</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Any-Observations?" data-toc-modified-id="Any-Observations?-2.4.0.1"><span class="toc-item-num">2.4.0.1&nbsp;&nbsp;</span>Any Observations?</a></span></li></ul></li></ul></li><li><span><a href="#Adding-to-a-DataFrame" data-toc-modified-id="Adding-to-a-DataFrame-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Adding to a DataFrame</a></span><ul class="toc-item"><li><span><a href="#Adding-Rows" data-toc-modified-id="Adding-Rows-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Adding Rows</a></span></li></ul></li><li><span><a href="#Adding-(and-Deleting)-Columns" data-toc-modified-id="Adding-(and-Deleting)-Columns-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Adding (and Deleting) Columns</a></span><ul class="toc-item"><li><span><a href="#DateTime-Data!" data-toc-modified-id="DateTime-Data!-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>DateTime Data!</a></span></li></ul></li></ul></li><li><span><a href="#Filtering" data-toc-modified-id="Filtering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Filtering</a></span><ul class="toc-item"><li><span><a href="#.loc" data-toc-modified-id=".loc-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><code>.loc</code></a></span><ul class="toc-item"><li><span><a href="#Your-turn!" data-toc-modified-id="Your-turn!-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Your turn!</a></span><ul class="toc-item"><li><span><a href="#Exercise-1" data-toc-modified-id="Exercise-1-3.1.1.1"><span class="toc-item-num">3.1.1.1&nbsp;&nbsp;</span>Exercise 1</a></span></li><li><span><a href="#Exercise-2" data-toc-modified-id="Exercise-2-3.1.1.2"><span class="toc-item-num">3.1.1.2&nbsp;&nbsp;</span>Exercise 2</a></span></li></ul></li></ul></li><li><span><a href="#.iloc" data-toc-modified-id=".iloc-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><code>.iloc</code></a></span></li></ul></li><li><span><a href="#Series-Methods" data-toc-modified-id="Series-Methods-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Series Methods</a></span><ul class="toc-item"><li><span><a href="#.value_counts()" data-toc-modified-id=".value_counts()-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><code>.value_counts()</code></a></span></li><li><span><a href="#.sort_values()" data-toc-modified-id=".sort_values()-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><code>.sort_values()</code></a></span></li></ul></li><li><span><a href="#Extra-Credit:-Find-a-.csv-file-online-and-experiment-with-it." data-toc-modified-id="Extra-Credit:-Find-a-.csv-file-online-and-experiment-with-it.-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Extra Credit: Find a .csv file online and experiment with it.</a></span></li></ul></div>

# %% [markdown]
# ![pandas](https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2880px-Pandas_logo.svg.png)

# %% [markdown]
# # Objectives

# %% [markdown]
# - Load .csv files into `pandas` DataFrames
# - Describe and manipulate data in Series and DataFrames

# %% [markdown]
# # What is Pandas?

# %% [markdown]
# ![I have no idea what I'm doing panda](https://cdn-images-1.medium.com/max/1600/1*oBx032ncOwLmCFX3Epo3Zg.jpeg)
#
# Just kidding - not actual literal pandas.

# %% [markdown]
# Pandas, as [the Anaconda docs](https://docs.anaconda.com/anaconda/packages/py3.7_osx-64/) tell us, offers us "High-performance, easy-to-use data structures and data analysis tools." It's something like "Excel for Python", but it's quite a bit more powerful. The name comes from "panel data", a common way to describe the kind of multidimensional data we'll be working with in certain academic circles (namely, statistics and econometrics) [[Source]](https://www.dlr.de/sc/Portaldata/15/Resources/dokumente/pyhpc2011/submissions/pyhpc2011_submission_9.pdf)
#
# In order to use pandas, we'll need to import it into our notebook first.
#
# pandas = advanced excel

# %%
# Import - using the common alias
import pandas as pd

# %% [markdown]
# ## Accessing Data
#
# ![pandas documentation image showcasing the kinds of data it can both read and write to](https://pandas.pydata.org/docs/_images/02_io_readwrite.svg)
#
# [[Image Source]](https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html)

# %% [markdown]
# Pandas can access a ton of different data types, including some that should be familiar: CSVs and JSONs! That's right, no more `with` / `open` statements now that we're using pandas!
#
# Most of the time, we'll see CSVs - so let's access a 'toy' data set quickly just to familiarize ourselves with using pandas. There's a heart dataset available in the data folder on this repository - let's read that in.

# %%
# Use read_csv to read in the heart csv file
# Need to assign it to a variable too - let's call this heart_df
# !ls data
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df = pd.read_csv('data/heart.csv')

# %% [markdown]
# The output of the `.read_csv()` function is a pandas *DataFrame*, which has a familiar tabaular structure of rows and columns.

# %%
# Let's check this variable out
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# What type is this variable?
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#dataframe versus series --> series if one dimensional

# %%
df[['age', 'sex']]
# Out:
#      age  sex
# 0     63    1
# 1     37    1
# 2     41    0
# 3     56    1
# 4     57    0
# ..   ...  ...
# 298   57    0
# 299   45    1
# 300   68    1
# 301   57    1
# 302   57    0
#
# [303 rows x 2 columns]

# %% [markdown]
# ## DataFrames and Series

# %% [markdown]
# Two main types of pandas objects are the DataFrame and the Series, the latter being in effect a single column of the former:

# %%
# Let's grab just one column
#need to do it in square brackets for lock statements. can do df.age for quick 
df['age']
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %% [markdown]
# Notice how we can isolate a column of our DataFrame simply by using square brackets together with the name of the column. We can also access columns as an attribute of the DataFrame - but that only works if the name of the column doesn't have any spaces or weird characters!

# %%
# What type is the column?
type(df['age'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Both Series and DataFrames have an *index* as well:

# %%
# Check out the dataframe index
#index is essentially the row number
df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
# Check out the series index
len(df['age'])
# Out:
# 303

# %%
df.age.index #give me the index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %% [markdown]
# DataFrames have columns - but a Series is just a single column, so it doesn't have the columns attribute.

# %%
# Check out the dataframe columns
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# Now try with the series
df[['age']].columns
# Out:
# Index(['age'], dtype='object')

# %% [markdown]
# Pandas is built on top of NumPy, and we can always access the NumPy array underlying a DataFrame using `.values`.

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
# Check out the dataframe values
df.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %% [markdown]
# ## More Basic DataFrame Attributes and Methods

# %% [markdown]
# ### `.head()` : first 5 rows

# %%
df.head(20)
#will automatically be 5 without a #
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# 12   49    1   1       130   266    0        1      171      0      0.6
# 13   64    1   3       110   211    0        0      144      1      1.8
# 14   58    0   3       150   283    1        0      162      0      1.0
# 15   50    0   2       120   219    0        1      158      0      1.6
# 16   58    0   2       120   340    0        1      172      0      0.0
# 17   66    0   3       150   226    0        1      114      0      2.6
# 18   43    1   0       150   247    0        1      171      0      1.5
# 19   69    0   3       140   239    0        1      151      0      1.8
#
#     slope  ca  thal  target
# 0       0   0     1       1
# 1       0   0     2       1
# 2       2   0     2       1
# 3       2   0     2       1
# 4       2   0     2       1
# 5       1   0     1       1
# 6       1   0     2       1
# 7       2   0     3       1
# 8       2   0     3       1
# 9       2   0     2       1
# 10      2   0     2       1
# 11      2   0     2       1
# 12      2   0     2       1
# 13      1   0     2       1
# 14      2   0     2       1
# 15      1   0     2       1
# 16      2   0     2       1
# 17      0   0     2       1
# 18      2   0     2       1
# 19      2   2     2       1

# %% [markdown]
# ### `.tail()` : last 5 rows

# %%
df.tail(20)
#will automatically be 5 without a #
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 283   40    1   0       152   223    0        1      181      0      0.0
# 284   61    1   0       140   207    0        0      138      1      1.9
# 285   46    1   0       140   311    0        1      120      1      1.8
# 286   59    1   3       134   204    0        1      162      0      0.8
# 287   57    1   1       154   232    0        0      164      0      0.0
# 288   57    1   0       110   335    0        1      143      1      3.0
# 289   55    0   0       128   205    0        2      130      1      2.0
# 290   61    1   0       148   203    0        1      161      0      0.0
# 291   58    1   0       114   318    0        2      140      0      4.4
# 292   58    0   0       170   225    1        0      146      1      2.8
# 293   67    1   2       152   212    0        0      150      0      0.8
# 294   44    1   0       120   169    0        1      144      1      2.8
# 295   63    1   0       140   187    0        0      144      1      4.0
# 296   63    0   0       124   197    0        1      136      1      0.0
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 283      2   0     3       0
# 284      2   1     3       0
# 285      1   2     3       0
# 286      2   2     2       0
# 287      2   1     2       0
# 288      1   1     3       0
# 289      1   1     3       0
# 290      2   1     3       0
# 291      0   3     1       0
# 292      1   2     1       0
# 293      1   0     3       0
# 294      0   0     1       0
# 295      2   2     3       0
# 296      1   0     2       0
# 297      1   2     1       0
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %% [markdown]
# ### `.info()` : information about the columns, including about nulls in those columns

# %%
#VERY IMPORTANT! what is this information about the dataframe. shows datatype for columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# ### `.describe()` : statistics about the data

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ### `.dtypes` : data types of each column

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %% [markdown]
# ### `.shape` : number of rows and columns

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# ### Statistics
#
# We saw them above, in the `.describe`, but we can also calculate statistics by calling them individually.

# %%
# Calculate the mean - for the whole dataframe!
df['age'].std()
# Out:
# 9.082100989837857

# %% [markdown]
# Let's pause and interpret - any observations?
#
# -

# %%
# Now min
df['age'].min()
# Out:
# 29

# %%
# And max
df['age'].max()
# Out:
# 77

# %% [markdown]
# ## Enough With The Small Stuff - Bring On Real Data!
#
# Let's access an open data portal and get some real live data!

# %% [markdown]
# Austin Animal Center Intake Data: https://data.austintexas.gov/Health-and-Community-Services/Austin-Animal-Center-Intakes/wter-evkm/

# %%
# !dir data
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 8EF7-A13E
#
#  Directory of C:\Users\Jackson\Desktop\NTL-DS-080723\1phase\data
#
# 08/10/2023  09:50 AM    <DIR>          .
# 08/11/2023  01:23 PM    <DIR>          ..
# 08/10/2023  09:50 AM             2,062 2019_Census_US_Population_Data_By_State_Lat_Long.csv
# 08/10/2023  09:50 AM        19,221,580 Austin_Animal_Center_Intakes-clean-year.csv
# 08/10/2023  09:50 AM        20,596,823 Austin_Animal_Center_Intakes_022822.csv
# 08/10/2023  09:50 AM        17,532,272 Austin_Animal_Center_Outcomes_022822.csv
# 08/10/2023  09:50 AM         1,521,008 BankChurners.csv
# 08/10/2023  09:50 AM         1,057,295 bundesliga.csv
# 08/10/2023  09:50 AM           164,902 classic-rock-song-list.csv
# 08/10/2023  09:50 AM         7,047,260 Datafiniti_Fast_Food.csv
# 08/10/2023  09:50 AM               101 ds_chars.csv
# 08/10/2023  09:50 AM            11,328 heart.csv
# 08/10/2023  09:50 AM            31,984 new_releases.json
# 08/10/2023  09:50 AM        15,638,996 OpenFoodFacts.csv
# 08/10/2023  09:50 AM         1,137,316 plants.json
# 08/10/2023  09:50 AM             2,848 pop_soda_data.csv
# 08/10/2023  09:50 AM               103 preferences.csv
# 08/10/2023  09:50 AM               136 states.csv
#               16 File(s)     83,966,014 bytes
#                2 Dir(s)  26,940,620,800 bytes free

# %%
intakes_url = pd.read_json('https://data.austintexas.gov/resource/wter-evkm.json')
intakes_url
# Out:
#     animal_id            datetime                datetime2  \
# 0     A665644 2013-10-21 07:59:00  2013-10-21T07:59:00.000
# 1     A665739 2013-10-22 11:11:00  2013-10-22T11:11:00.000
# 2     A665763 2013-10-22 15:10:00  2013-10-22T15:10:00.000
# 3     A379998 2013-10-23 11:42:00  2013-10-23T11:42:00.000
# 4     A634503 2013-10-01 14:49:00  2013-10-01T14:49:00.000
# ..        ...                 ...                      ...
# 995   A664268 2013-10-01 12:05:00  2013-10-01T12:05:00.000
# 996   A656696 2013-10-13 12:52:00  2013-10-13T12:52:00.000
# 997   A665285 2013-10-15 18:19:00  2013-10-15T18:19:00.000
# 998   A665185 2013-10-14 18:32:00  2013-10-14T18:32:00.000
# 999   A665572 2013-10-19 14:09:00  2013-10-19T14:09:00.000
#
#                                    found_location      intake_type  \
# 0                                     Austin (TX)            Stray
# 1                                     Austin (TX)            Stray
# 2    E Riverside Dr/Royal Crest Dr in Austin (TX)            Stray
# 3                  51St And Grover in Austin (TX)            Stray
# 4                                      Manor (TX)  Owner Surrender
# ..                                            ...              ...
# 995                                   Austin (TX)            Stray
# 996                                   Austin (TX)  Owner Surrender
# 997              4807 Airport Blvd in Austin (TX)            Stray
# 998              Hwy 183/Burnet Rd in Austin (TX)            Stray
# 999   900 Broken Feather Trl in Pflugerville (TX)            Stray
#
#     intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0               Sick         Cat   Intact Female         4 weeks
# 1             Normal         Cat   Intact Female         1 month
# 2             Normal         Dog     Intact Male        4 months
# 3             Normal         Dog     Intact Male        10 years
# 4             Normal         Dog   Spayed Female         2 years
# ..               ...         ...             ...             ...
# 995           Normal         Cat   Intact Female         3 years
# 996           Normal         Cat   Spayed Female         2 years
# 997           Normal         Cat   Intact Female        5 months
# 998           Normal         Cat     Intact Male         3 weeks
# 999           Normal         Dog     Intact Male          1 year
#
#                         breed              color      name
# 0      Domestic Shorthair Mix             Calico       NaN
# 1    Domestic Medium Hair Mix              Black    *Alana
# 2           Cairn Terrier Mix          Tan/White       NaN
# 3                    Pit Bull              Black  Disciple
# 4         Norfolk Terrier Mix                Tan     Otter
# ..                        ...                ...       ...
# 995          Russian Blue Mix               Blue   *Kochka
# 996    Domestic Shorthair Mix        Brown Tabby    *Angel
# 997    Domestic Shorthair Mix             Torbie     Tabby
# 998    Domestic Shorthair Mix  Brown Tabby/White    *Vince
# 999        Great Pyrenees Mix              White       NaN
#
# [1000 rows x 12 columns]

# %%
# Same as the JSON output from this API endpoint, but different levels of detail for dates!
intakes_url.shape
# Out:
# (1000, 12)

# %%
# But this is only 1000 rows... website says there's 136K rows!

# %%
# It's a limitation of the API - let's just download the data instead
# It's in the data folder
intakes_url = pd.read_csv('data/Austin_Animal_Center_intakes-clean-year.csv')

# %%
# Now let's explore those earlier attributes and methods on this dataset!
# Check the first 5 rows
intakes_url.head()
# Out:
#   Animal ID     Name             DateTime  Year  \
# 0   A786884   *Brock  2019-01-03 16:19:00  2019
# 1   A706918    Belle  2015-07-05 12:59:00  2015
# 2   A724273  Runster  2016-04-14 18:43:00  2016
# 3   A665644      NaN  2013-10-21 07:59:00  2013
# 4   A682524      Rio  2014-06-29 10:38:00  2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
# Check the last 5 rows
intakes_url.tail()
# Out:
#        Animal ID     Name             DateTime  Year  \
# 136758   A852238  A852238  2022-02-28 14:02:00  2022
# 136759   A852221     Coco  2022-02-28 11:05:00  2022
# 136760   A851977    *Jack  2022-02-22 13:34:00  2022
# 136761   A852127    Sonic  2022-02-25 13:05:00  2022
# 136762   A852194    Queen  2022-02-27 13:44:00  2022
#
#                                     Found Location Intake Type  \
# 136758  Cameron And Crosspark Drive in Austin (TX)       Stray
# 136759                   45 And 183 in Travis (TX)       Stray
# 136760        1200 Montopolis Drive in Austin (TX)       Stray
# 136761      7601 Daffan Ln Unit 424 in Austin (TX)       Stray
# 136762            8071 N Lamar Blvd in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                 Breed         Color
# 136758         Labrador Retriever Mix   Black/White
# 136759                 Great Pyrenees         White
# 136760  Chihuahua Shorthair/Dachshund   Black/White
# 136761                   Pit Bull Mix  White/Yellow
# 136762                     Cane Corso    Blue Cream

# %%
# Check the shape
intakes_url.shape
# Out:
# (136763, 12)

# %%
# Check the datatypes
intakes_url.dtypes
# Out:
# Animal ID           object
# Name                object
# DateTime            object
# Year                 int64
# Found Location      object
# Intake Type         object
# Intake Condition    object
# Animal Type         object
# Sex upon Intake     object
# Age upon Intake     object
# Breed               object
# Color               object
# dtype: object

# %%
# Check more general information on the dataframe
intakes_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136763 entries, 0 to 136762
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         136763 non-null  object
#  1   Name              95772 non-null   object
#  2   DateTime          136763 non-null  object
#  3   Year              136763 non-null  int64
#  4   Found Location    136763 non-null  object
#  5   Intake Type       136763 non-null  object
#  6   Intake Condition  136763 non-null  object
#  7   Animal Type       136763 non-null  object
#  8   Sex upon Intake   136762 non-null  object
#  9   Age upon Intake   136763 non-null  object
#  10  Breed             136763 non-null  object
#  11  Color             136763 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 12.5+ MB

# %%
# Check summary/descriptive statistics on the dataframe
intakes_url.describe()
# Out:
#                 Year
# count  136763.000000
# mean     2017.100692
# std         2.328994
# min      2013.000000
# 25%      2015.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2022.000000

# %% [markdown]
# #### Any Observations?
#
# -

# %% [markdown]
# ## Adding to a DataFrame

# %% [markdown]
# ### Adding Rows

# %% [markdown]
# We have a new animal coming in, captured here in a Python dictionary:

# %%
# Dictionary, where keys match the column names and values are the row values
next_row = {'Animal ID': 'A851755',
            'Name': "T'Challa",
            'DateTime': '2/28/2022 11:25:00 AM',
            'MonthYear': 'February 2022',
            'Found Location': 'Houston (TX)',
            'Intake Type': 'Public Assist',
            'Intake Condition': 'Normal',
            'Animal Type': 'Cat',
            'Sex upon Intake': 'Neutered Male',
            'Age upon Intake': '4 years',
            'Breed': 'Domestic Shorthair',
            'Color': 'Black'}
next_row
# Out:
# {'Animal ID': 'A851755',
#  'Name': "T'Challa",
#  'DateTime': '2/28/2022 11:25:00 AM',
#  'MonthYear': 'February 2022',
#  'Found Location': 'Houston (TX)',
#  'Intake Type': 'Public Assist',
#  'Intake Condition': 'Normal',
#  'Animal Type': 'Cat',
#  'Sex upon Intake': 'Neutered Male',
#  'Age upon Intake': '4 years',
#  'Breed': 'Domestic Shorthair',
#  'Color': 'Black'}

# %% [markdown]
# How can we add this to the bottom of our dataset?

# %%
# Let's first turn this into a DataFrame.
# We can use the .from_dict() method.
new_animal = pd.DataFrame.from_dict(next_row, orient = 'index').T
new_animal
# Out:
#   Animal ID      Name               DateTime      MonthYear Found Location  \
# 0   A851755  T'Challa  2/28/2022 11:25:00 AM  February 2022   Houston (TX)
#
#      Intake Type Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0  Public Assist           Normal         Cat   Neutered Male         4 years
#
#                 Breed  Color
# 0  Domestic Shorthair  Black

# %%
intakes_url
# Out:
#        Animal ID     Name             DateTime  Year  \
# 0        A786884   *Brock  2019-01-03 16:19:00  2019
# 1        A706918    Belle  2015-07-05 12:59:00  2015
# 2        A724273  Runster  2016-04-14 18:43:00  2016
# 3        A665644      NaN  2013-10-21 07:59:00  2013
# 4        A682524      Rio  2014-06-29 10:38:00  2014
# ...          ...      ...                  ...   ...
# 136758   A852238  A852238  2022-02-28 14:02:00  2022
# 136759   A852221     Coco  2022-02-28 11:05:00  2022
# 136760   A851977    *Jack  2022-02-22 13:34:00  2022
# 136761   A852127    Sonic  2022-02-25 13:05:00  2022
# 136762   A852194    Queen  2022-02-27 13:44:00  2022
#
#                                     Found Location Intake Type  \
# 0              2501 Magin Meadow Dr in Austin (TX)       Stray
# 1                 9409 Bluegrass Dr in Austin (TX)       Stray
# 2               2818 Palomino Trail in Austin (TX)       Stray
# 3                                      Austin (TX)       Stray
# 4                    800 Grove Blvd in Austin (TX)       Stray
# ...                                            ...         ...
# 136758  Cameron And Crosspark Drive in Austin (TX)       Stray
# 136759                   45 And 183 in Travis (TX)       Stray
# 136760        1200 Montopolis Drive in Austin (TX)       Stray
# 136761      7601 Daffan Ln Unit 424 in Austin (TX)       Stray
# 136762            8071 N Lamar Blvd in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                         Breed         Color
# 0                                  Beagle Mix      Tricolor
# 1                    English Springer Spaniel   White/Liver
# 2                                 Basenji Mix   Sable/White
# 3                      Domestic Shorthair Mix        Calico
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray
# ...                                       ...           ...
# 136758                 Labrador Retriever Mix   Black/White
# 136759                         Great Pyrenees         White
# 136760          Chihuahua Shorthair/Dachshund   Black/White
# 136761                           Pit Bull Mix  White/Yellow
# 136762                             Cane Corso    Blue Cream
#
# [136763 rows x 12 columns]

# %%
pd.concat([intakes_url,new_animal], axis = 0)
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 0        A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 0                                 Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 0                Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 0                          Domestic Shorthair         Black  February 2022
#
# [136764 rows x 13 columns]

# %%
# Now we just need to concatenate the two DataFrames together.
# Note the `ignore_index` parameter! We'll set that to True.
animals = pd.concat([intakes_url,new_animal], ignore_index = True)
animals
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
# [136764 rows x 13 columns]

# %% [markdown]
# ## Adding (and Deleting) Columns

# %% [markdown]
# Adding a column is very easy in `pandas`. Let's add a new column to our dataset called "test", and set all of its values to 0.

# %%
# Create a new column, 'test', where every value in the col is 0
animals['test'] = 0

# %%
# Sanity check
animals
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear  \
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
#         test
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 136759     0
# 136760     0
# 136761     0
# 136762     0
# 136763     0
#
# [136764 rows x 14 columns]

# %% [markdown]
# But we don't need that - let's drop that column.

# %%
# Drop that test column
animals.drop(columns = ['test'], inplace = True)

# %%
# Sanity check
animals
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
# [136764 rows x 13 columns]

# %% [markdown]
# We can also do math with columns, or use mathematical notation to combine columns even when they aren't numerical!
#
# We don't have any numeric data in this current dataset. But we can still create a combined "Type" column that combines the values of our Intake Type and Animal Type columns.

# %%
# Create a new column, 'Type', from the two 'Type' columns
animals['Type'] = animals['Intake Type'] + animals['Animal Type']

# %%
# Sanity check
animals
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear  \
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
#                     type              Type
# 0               StrayDog          StrayDog
# 1               StrayDog          StrayDog
# 2               StrayDog          StrayDog
# 3               StrayCat          StrayCat
# 4               StrayDog          StrayDog
# ...                  ...               ...
# 136759          StrayDog          StrayDog
# 136760          StrayDog          StrayDog
# 136761          StrayDog          StrayDog
# 136762          StrayDog          StrayDog
# 136763  Public AssistCat  Public AssistCat
#
# [136764 rows x 15 columns]

# %%
animals['Year Plus 5'] = animals['Year'] + 5

# %%
animals
# Out:
#        Animal ID      Name               DateTime    Year  \
# 0        A786884    *Brock    2019-01-03 16:19:00  2019.0
# 1        A706918     Belle    2015-07-05 12:59:00  2015.0
# 2        A724273   Runster    2016-04-14 18:43:00  2016.0
# 3        A665644       NaN    2013-10-21 07:59:00  2013.0
# 4        A682524       Rio    2014-06-29 10:38:00  2014.0
# ...          ...       ...                    ...     ...
# 136759   A852221      Coco    2022-02-28 11:05:00  2022.0
# 136760   A851977     *Jack    2022-02-22 13:34:00  2022.0
# 136761   A852127     Sonic    2022-02-25 13:05:00  2022.0
# 136762   A852194     Queen    2022-02-27 13:44:00  2022.0
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM     NaN
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear  \
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
#                     type              Type  Year Plus 5
# 0               StrayDog          StrayDog       2024.0
# 1               StrayDog          StrayDog       2020.0
# 2               StrayDog          StrayDog       2021.0
# 3               StrayCat          StrayCat       2018.0
# 4               StrayDog          StrayDog       2019.0
# ...                  ...               ...          ...
# 136759          StrayDog          StrayDog       2027.0
# 136760          StrayDog          StrayDog       2027.0
# 136761          StrayDog          StrayDog       2027.0
# 136762          StrayDog          StrayDog       2027.0
# 136763  Public AssistCat  Public AssistCat          NaN
#
# [136764 rows x 16 columns]

# %% [markdown]
# ### DateTime Data!
#
# Useful reference: https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html

# %% [markdown]
# I mentioned we don't have any numeric data in here... let's make a new numeric column! Specifically, let's grab the year from our `DateTime` column and use that to create a new `Year` column. AKA, let's learn how to deal with datetime data!

# %%
animals.dtypes
# Out:
# Animal ID                   object
# Name                        object
# DateTime                    object
# Year                datetime64[ns]
# Found Location              object
# Intake Type                 object
# Intake Condition            object
# Animal Type                 object
# Sex upon Intake             object
# Age upon Intake             object
# Breed                       object
# Color                       object
# MonthYear                   object
# type                        object
# Type                        object
# Year Plus 5                float64
# dtype: object

# %%
# What type is the DateTime column now?
animals['Year'] = pd.to_datetime(animals['Year'])

# %%
# Let's make that a datetime datatype

# %%
# Sanity check

# %%
# Now we can access parts of a datetime object using .dt - an attribute!
animals['Year'].dt.month
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 136759    1.0
# 136760    1.0
# 136761    1.0
# 136762    1.0
# 136763    NaN
# Name: Year, Length: 136764, dtype: float64

# %%
animals['Year'].dt.year
# Out:
# 0         1970.0
# 1         1970.0
# 2         1970.0
# 3         1970.0
# 4         1970.0
#            ...
# 136759    1970.0
# 136760    1970.0
# 136761    1970.0
# 136762    1970.0
# 136763       NaN
# Name: Year, Length: 136764, dtype: float64

# %%
animals['Year'].dt.dayofweek
# Out:
# 0         3.0
# 1         3.0
# 2         3.0
# 3         3.0
# 4         3.0
#          ...
# 136759    3.0
# 136760    3.0
# 136761    3.0
# 136762    3.0
# 136763    NaN
# Name: Year, Length: 136764, dtype: float64

# %%
animals['Year'].dt.day
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 136759    1.0
# 136760    1.0
# 136761    1.0
# 136762    1.0
# 136763    NaN
# Name: Year, Length: 136764, dtype: float64

# %%
# Make that into a new column
animals['Day of Week'] = animals['Year'].dt.dayofweek

# %%
# Sanity check
animals
# Out:
#        Animal ID      Name               DateTime  \
# 0        A786884    *Brock    2019-01-03 16:19:00
# 1        A706918     Belle    2015-07-05 12:59:00
# 2        A724273   Runster    2016-04-14 18:43:00
# 3        A665644       NaN    2013-10-21 07:59:00
# 4        A682524       Rio    2014-06-29 10:38:00
# ...          ...       ...                    ...
# 136759   A852221      Coco    2022-02-28 11:05:00
# 136760   A851977     *Jack    2022-02-22 13:34:00
# 136761   A852127     Sonic    2022-02-25 13:05:00
# 136762   A852194     Queen    2022-02-27 13:44:00
# 136763   A851755  T'Challa  2/28/2022 11:25:00 AM
#
#                                 Year                          Found Location  \
# 0      1970-01-01 00:00:00.000002019     2501 Magin Meadow Dr in Austin (TX)
# 1      1970-01-01 00:00:00.000002015        9409 Bluegrass Dr in Austin (TX)
# 2      1970-01-01 00:00:00.000002016      2818 Palomino Trail in Austin (TX)
# 3      1970-01-01 00:00:00.000002013                             Austin (TX)
# 4      1970-01-01 00:00:00.000002014           800 Grove Blvd in Austin (TX)
# ...                              ...                                     ...
# 136759 1970-01-01 00:00:00.000002022               45 And 183 in Travis (TX)
# 136760 1970-01-01 00:00:00.000002022    1200 Montopolis Drive in Austin (TX)
# 136761 1970-01-01 00:00:00.000002022  7601 Daffan Ln Unit 424 in Austin (TX)
# 136762 1970-01-01 00:00:00.000002022        8071 N Lamar Blvd in Austin (TX)
# 136763                           NaT                            Houston (TX)
#
#           Intake Type Intake Condition Animal Type Sex upon Intake  \
# 0               Stray           Normal         Dog   Neutered Male
# 1               Stray           Normal         Dog   Spayed Female
# 2               Stray           Normal         Dog     Intact Male
# 3               Stray             Sick         Cat   Intact Female
# 4               Stray           Normal         Dog   Neutered Male
# ...               ...              ...         ...             ...
# 136759          Stray           Normal         Dog     Intact Male
# 136760          Stray           Normal         Dog     Intact Male
# 136761          Stray           Normal         Dog     Intact Male
# 136762          Stray           Normal         Dog   Intact Female
# 136763  Public Assist           Normal         Cat   Neutered Male
#
#        Age upon Intake                                  Breed         Color  \
# 0              2 years                             Beagle Mix      Tricolor
# 1              8 years               English Springer Spaniel   White/Liver
# 2            11 months                            Basenji Mix   Sable/White
# 3              4 weeks                 Domestic Shorthair Mix        Calico
# 4              4 years  Doberman Pinsch/Australian Cattle Dog      Tan/Gray
# ...                ...                                    ...           ...
# 136759         3 years                         Great Pyrenees         White
# 136760         2 years          Chihuahua Shorthair/Dachshund   Black/White
# 136761         2 years                           Pit Bull Mix  White/Yellow
# 136762        4 months                             Cane Corso    Blue Cream
# 136763         4 years                     Domestic Shorthair         Black
#
#             MonthYear              type              Type  Year Plus 5  \
# 0                 NaN          StrayDog          StrayDog       2024.0
# 1                 NaN          StrayDog          StrayDog       2020.0
# 2                 NaN          StrayDog          StrayDog       2021.0
# 3                 NaN          StrayCat          StrayCat       2018.0
# 4                 NaN          StrayDog          StrayDog       2019.0
# ...               ...               ...               ...          ...
# 136759            NaN          StrayDog          StrayDog       2027.0
# 136760            NaN          StrayDog          StrayDog       2027.0
# 136761            NaN          StrayDog          StrayDog       2027.0
# 136762            NaN          StrayDog          StrayDog       2027.0
# 136763  February 2022  Public AssistCat  Public AssistCat          NaN
#
#         Day of Week
# 0               3.0
# 1               3.0
# 2               3.0
# 3               3.0
# 4               3.0
# ...             ...
# 136759          3.0
# 136760          3.0
# 136761          3.0
# 136762          3.0
# 136763          NaN
#
# [136764 rows x 17 columns]

# %%
animals['DateTime'] = pd.to_datetime(animals['DateTime'])

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136764 entries, 0 to 136763
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         136764 non-null  object
#  1   Name              95773 non-null   object
#  2   DateTime          136764 non-null  datetime64[ns]
#  3   Year              136763 non-null  datetime64[ns]
#  4   Found Location    136764 non-null  object
#  5   Intake Type       136764 non-null  object
#  6   Intake Condition  136764 non-null  object
#  7   Animal Type       136764 non-null  object
#  8   Sex upon Intake   136763 non-null  object
#  9   Age upon Intake   136764 non-null  object
#  10  Breed             136764 non-null  object
#  11  Color             136764 non-null  object
#  12  MonthYear         1 non-null       object
#  13  type              136764 non-null  object
#  14  Type              136764 non-null  object
#  15  Year Plus 5       136763 non-null  float64
#  16  Day of Week       136763 non-null  float64
#  17  Intake Year       136764 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(2), object(13)
# memory usage: 18.8+ MB

# %% [markdown]
# # Filtering

# %% [markdown]
# We can use filtering techniques to see only certain rows of our data. Let's look at only animals taken into the center during or after 2020:

# %%
animals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136764 entries, 0 to 136763
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         136764 non-null  object
#  1   Name              95773 non-null   object
#  2   DateTime          136764 non-null  datetime64[ns]
#  3   Year              136763 non-null  datetime64[ns]
#  4   Found Location    136764 non-null  object
#  5   Intake Type       136764 non-null  object
#  6   Intake Condition  136764 non-null  object
#  7   Animal Type       136764 non-null  object
#  8   Sex upon Intake   136763 non-null  object
#  9   Age upon Intake   136764 non-null  object
#  10  Breed             136764 non-null  object
#  11  Color             136764 non-null  object
#  12  MonthYear         1 non-null       object
#  13  type              136764 non-null  object
#  14  Type              136764 non-null  object
#  15  Year Plus 5       136763 non-null  float64
#  16  Day of Week       136763 non-null  float64
#  17  Intake Year       136764 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(2), object(13)
# memory usage: 18.8+ MB

# %%
animals['Year'] = animals['DateTime'].dt.year

# %%
animals
# Out:
#        Animal ID      Name            DateTime  Year  \
# 0        A786884    *Brock 2019-01-03 16:19:00  2019
# 1        A706918     Belle 2015-07-05 12:59:00  2015
# 2        A724273   Runster 2016-04-14 18:43:00  2016
# 3        A665644       NaN 2013-10-21 07:59:00  2013
# 4        A682524       Rio 2014-06-29 10:38:00  2014
# ...          ...       ...                 ...   ...
# 136759   A852221      Coco 2022-02-28 11:05:00  2022
# 136760   A851977     *Jack 2022-02-22 13:34:00  2022
# 136761   A852127     Sonic 2022-02-25 13:05:00  2022
# 136762   A852194     Queen 2022-02-27 13:44:00  2022
# 136763   A851755  T'Challa 2022-02-28 11:25:00  2022
#
#                                 Found Location    Intake Type  \
# 0          2501 Magin Meadow Dr in Austin (TX)          Stray
# 1             9409 Bluegrass Dr in Austin (TX)          Stray
# 2           2818 Palomino Trail in Austin (TX)          Stray
# 3                                  Austin (TX)          Stray
# 4                800 Grove Blvd in Austin (TX)          Stray
# ...                                        ...            ...
# 136759               45 And 183 in Travis (TX)          Stray
# 136760    1200 Montopolis Drive in Austin (TX)          Stray
# 136761  7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762        8071 N Lamar Blvd in Austin (TX)          Stray
# 136763                            Houston (TX)  Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                         Breed         Color      MonthYear  \
# 0                                  Beagle Mix      Tricolor            NaN
# 1                    English Springer Spaniel   White/Liver            NaN
# 2                                 Basenji Mix   Sable/White            NaN
# 3                      Domestic Shorthair Mix        Calico            NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray            NaN
# ...                                       ...           ...            ...
# 136759                         Great Pyrenees         White            NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                           Pit Bull Mix  White/Yellow            NaN
# 136762                             Cane Corso    Blue Cream            NaN
# 136763                     Domestic Shorthair         Black  February 2022
#
#                     type              Type  Year Plus 5  Day of Week  \
# 0               StrayDog          StrayDog       2024.0          3.0
# 1               StrayDog          StrayDog       2020.0          3.0
# 2               StrayDog          StrayDog       2021.0          3.0
# 3               StrayCat          StrayCat       2018.0          3.0
# 4               StrayDog          StrayDog       2019.0          3.0
# ...                  ...               ...          ...          ...
# 136759          StrayDog          StrayDog       2027.0          3.0
# 136760          StrayDog          StrayDog       2027.0          3.0
# 136761          StrayDog          StrayDog       2027.0          3.0
# 136762          StrayDog          StrayDog       2027.0          3.0
# 136763  Public AssistCat  Public AssistCat          NaN          NaN
#
#                Intake Year
# 0      2019-01-03 16:19:00
# 1      2015-07-05 12:59:00
# 2      2016-04-14 18:43:00
# 3      2013-10-21 07:59:00
# 4      2014-06-29 10:38:00
# ...                    ...
# 136759 2022-02-28 11:05:00
# 136760 2022-02-22 13:34:00
# 136761 2022-02-25 13:05:00
# 136762 2022-02-27 13:44:00
# 136763 2022-02-28 11:25:00
#
# [136764 rows x 18 columns]

# %%
# Check which rows have an intake year greater than or equal to 2020
animals.loc[animals['Year'] >= 2020]
# Out:
#        Animal ID      Name            DateTime  Year  \
# 7        A844350     *Ella 2021-10-15 11:40:00  2021
# 9        A818975       NaN 2020-06-18 14:53:00  2020
# 22       A831808       NaN 2021-04-02 11:16:00  2021
# 24       A836850       NaN 2021-06-15 12:37:00  2021
# 26       A815227      Baby 2020-03-12 13:52:00  2020
# ...          ...       ...                 ...   ...
# 136759   A852221      Coco 2022-02-28 11:05:00  2022
# 136760   A851977     *Jack 2022-02-22 13:34:00  2022
# 136761   A852127     Sonic 2022-02-25 13:05:00  2022
# 136762   A852194     Queen 2022-02-27 13:44:00  2022
# 136763   A851755  T'Challa 2022-02-28 11:25:00  2022
#
#                                        Found Location      Intake Type  \
# 7       2112 East William Cannon Drive in Austin (TX)            Stray
# 9               Braker Lane And Metric in Travis (TX)            Stray
# 22                                        Austin (TX)  Owner Surrender
# 24                 6111 Softwood Drive in Austin (TX)    Public Assist
# 26                   12305 Zeller Lane in Austin (TX)            Stray
# ...                                               ...              ...
# 136759                      45 And 183 in Travis (TX)            Stray
# 136760           1200 Montopolis Drive in Austin (TX)            Stray
# 136761         7601 Daffan Ln Unit 424 in Austin (TX)            Stray
# 136762               8071 N Lamar Blvd in Austin (TX)            Stray
# 136763                                   Houston (TX)    Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 7                Normal         Cat   Intact Female        6 months
# 9                Normal         Cat     Intact Male         4 weeks
# 22               Normal         Cat   Intact Female         1 month
# 24             Pregnant         Dog   Intact Female         4 years
# 26               Normal         Dog   Intact Female         1 month
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                 Breed         Color      MonthYear  \
# 7                  Domestic Shorthair   Brown Tabby            NaN
# 9                  Domestic Shorthair   Cream Tabby            NaN
# 22             Domestic Shorthair Mix        Tortie            NaN
# 24                           Pit Bull    Blue/White            NaN
# 26                    Norfolk Terrier   Brown/Cream            NaN
# ...                               ...           ...            ...
# 136759                 Great Pyrenees         White            NaN
# 136760  Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                   Pit Bull Mix  White/Yellow            NaN
# 136762                     Cane Corso    Blue Cream            NaN
# 136763             Domestic Shorthair         Black  February 2022
#
#                       type                Type  Year Plus 5  Day of Week  \
# 7                 StrayCat            StrayCat       2026.0          3.0
# 9                 StrayCat            StrayCat       2025.0          3.0
# 22      Owner SurrenderCat  Owner SurrenderCat       2026.0          3.0
# 24        Public AssistDog    Public AssistDog       2026.0          3.0
# 26                StrayDog            StrayDog       2025.0          3.0
# ...                    ...                 ...          ...          ...
# 136759            StrayDog            StrayDog       2027.0          3.0
# 136760            StrayDog            StrayDog       2027.0          3.0
# 136761            StrayDog            StrayDog       2027.0          3.0
# 136762            StrayDog            StrayDog       2027.0          3.0
# 136763    Public AssistCat    Public AssistCat          NaN          NaN
#
#                Intake Year
# 7      2021-10-15 11:40:00
# 9      2020-06-18 14:53:00
# 22     2021-04-02 11:16:00
# 24     2021-06-15 12:37:00
# 26     2020-03-12 13:52:00
# ...                    ...
# 136759 2022-02-28 11:05:00
# 136760 2022-02-22 13:34:00
# 136761 2022-02-25 13:05:00
# 136762 2022-02-27 13:44:00
# 136763 2022-02-28 11:25:00
#
# [23270 rows x 18 columns]

# %%
animals.loc[animals['Intake Type'] == 'Stray']
# Out:
#        Animal ID     Name            DateTime  Year  \
# 0        A786884   *Brock 2019-01-03 16:19:00  2019
# 1        A706918    Belle 2015-07-05 12:59:00  2015
# 2        A724273  Runster 2016-04-14 18:43:00  2016
# 3        A665644      NaN 2013-10-21 07:59:00  2013
# 4        A682524      Rio 2014-06-29 10:38:00  2014
# ...          ...      ...                 ...   ...
# 136758   A852238  A852238 2022-02-28 14:02:00  2022
# 136759   A852221     Coco 2022-02-28 11:05:00  2022
# 136760   A851977    *Jack 2022-02-22 13:34:00  2022
# 136761   A852127    Sonic 2022-02-25 13:05:00  2022
# 136762   A852194    Queen 2022-02-27 13:44:00  2022
#
#                                     Found Location Intake Type  \
# 0              2501 Magin Meadow Dr in Austin (TX)       Stray
# 1                 9409 Bluegrass Dr in Austin (TX)       Stray
# 2               2818 Palomino Trail in Austin (TX)       Stray
# 3                                      Austin (TX)       Stray
# 4                    800 Grove Blvd in Austin (TX)       Stray
# ...                                            ...         ...
# 136758  Cameron And Crosspark Drive in Austin (TX)       Stray
# 136759                   45 And 183 in Travis (TX)       Stray
# 136760        1200 Montopolis Drive in Austin (TX)       Stray
# 136761      7601 Daffan Ln Unit 424 in Austin (TX)       Stray
# 136762            8071 N Lamar Blvd in Austin (TX)       Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 0                Normal         Dog   Neutered Male         2 years
# 1                Normal         Dog   Spayed Female         8 years
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 4                Normal         Dog   Neutered Male         4 years
# ...                 ...         ...             ...             ...
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                         Breed         Color MonthYear  \
# 0                                  Beagle Mix      Tricolor       NaN
# 1                    English Springer Spaniel   White/Liver       NaN
# 2                                 Basenji Mix   Sable/White       NaN
# 3                      Domestic Shorthair Mix        Calico       NaN
# 4       Doberman Pinsch/Australian Cattle Dog      Tan/Gray       NaN
# ...                                       ...           ...       ...
# 136758                 Labrador Retriever Mix   Black/White       NaN
# 136759                         Great Pyrenees         White       NaN
# 136760          Chihuahua Shorthair/Dachshund   Black/White       NaN
# 136761                           Pit Bull Mix  White/Yellow       NaN
# 136762                             Cane Corso    Blue Cream       NaN
#
#             type      Type  Year Plus 5  Day of Week         Intake Year
# 0       StrayDog  StrayDog       2024.0          3.0 2019-01-03 16:19:00
# 1       StrayDog  StrayDog       2020.0          3.0 2015-07-05 12:59:00
# 2       StrayDog  StrayDog       2021.0          3.0 2016-04-14 18:43:00
# 3       StrayCat  StrayCat       2018.0          3.0 2013-10-21 07:59:00
# 4       StrayDog  StrayDog       2019.0          3.0 2014-06-29 10:38:00
# ...          ...       ...          ...          ...                 ...
# 136758  StrayDog  StrayDog       2027.0          3.0 2022-02-28 14:02:00
# 136759  StrayDog  StrayDog       2027.0          3.0 2022-02-28 11:05:00
# 136760  StrayDog  StrayDog       2027.0          3.0 2022-02-22 13:34:00
# 136761  StrayDog  StrayDog       2027.0          3.0 2022-02-25 13:05:00
# 136762  StrayDog  StrayDog       2027.0          3.0 2022-02-27 13:44:00
#
# [94180 rows x 18 columns]

# %%
animals[animals['Year'] == 2020]
# Out:
#        Animal ID      Name            DateTime  Year  \
# 9        A818975       NaN 2020-06-18 14:53:00  2020
# 26       A815227      Baby 2020-03-12 13:52:00  2020
# 44       A821389  *Dim Sum 2020-08-10 14:10:00  2020
# 47       A812244       NaN 2020-01-18 14:14:00  2020
# 71       A813757       NaN 2020-02-18 12:26:00  2020
# ...          ...       ...                 ...   ...
# 136355   A814134      C'Lo 2020-04-13 19:27:00  2020
# 136358   A814134      C'Lo 2020-02-24 18:15:00  2020
# 136359   A814134      C'Lo 2020-06-10 18:27:00  2020
# 136361   A814134      C'Lo 2020-03-30 08:31:00  2020
# 136541   A823070      Luna 2020-09-15 14:47:00  2020
#
#                                    Found Location      Intake Type  \
# 9           Braker Lane And Metric in Travis (TX)            Stray
# 26               12305 Zeller Lane in Austin (TX)            Stray
# 44       7800 San Felipe Boulevard in Austin (TX)            Stray
# 47                                    Travis (TX)  Owner Surrender
# 71      Colonial Park And Weidemar in Austin (TX)            Stray
# ...                                           ...              ...
# 136355               Little Pebble in Austin (TX)            Stray
# 136358         10409 Little Pebble in Austin (TX)        Abandoned
# 136359                          Pflugerville (TX)  Owner Surrender
# 136361                                Austin (TX)        Abandoned
# 136541                                Austin (TX)  Owner Surrender
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 9                Normal         Cat     Intact Male         4 weeks
# 26               Normal         Dog   Intact Female         1 month
# 44               Normal         Cat     Intact Male         4 weeks
# 47               Normal         Dog     Intact Male         1 month
# 71               Normal         Dog   Intact Female          1 year
# ...                 ...         ...             ...             ...
# 136355          Injured         Dog   Neutered Male          1 year
# 136358           Normal         Dog     Intact Male          1 year
# 136359           Normal         Dog   Neutered Male          1 year
# 136361           Normal         Dog   Neutered Male          1 year
# 136541           Normal         Cat   Intact Female          1 year
#
#                                         Breed           Color MonthYear  \
# 9                          Domestic Shorthair     Cream Tabby       NaN
# 26                            Norfolk Terrier     Brown/Cream       NaN
# 44                         Domestic Shorthair     Brown Tabby       NaN
# 47                         Labrador Retriever             Tan       NaN
# 71      German Shepherd/Australian Cattle Dog  Black/Tricolor       NaN
# ...                                       ...             ...       ...
# 136355                           Pit Bull Mix     White/Black       NaN
# 136358                           Pit Bull Mix     White/Black       NaN
# 136359                           Pit Bull Mix     White/Black       NaN
# 136361                           Pit Bull Mix     White/Black       NaN
# 136541                     Domestic Shorthair      Blue/White       NaN
#
#                       type                Type  Year Plus 5  Day of Week  \
# 9                 StrayCat            StrayCat       2025.0          3.0
# 26                StrayDog            StrayDog       2025.0          3.0
# 44                StrayCat            StrayCat       2025.0          3.0
# 47      Owner SurrenderDog  Owner SurrenderDog       2025.0          3.0
# 71                StrayDog            StrayDog       2025.0          3.0
# ...                    ...                 ...          ...          ...
# 136355            StrayDog            StrayDog       2025.0          3.0
# 136358        AbandonedDog        AbandonedDog       2025.0          3.0
# 136359  Owner SurrenderDog  Owner SurrenderDog       2025.0          3.0
# 136361        AbandonedDog        AbandonedDog       2025.0          3.0
# 136541  Owner SurrenderCat  Owner SurrenderCat       2025.0          3.0
#
#                Intake Year
# 9      2020-06-18 14:53:00
# 26     2020-03-12 13:52:00
# 44     2020-08-10 14:10:00
# 47     2020-01-18 14:14:00
# 71     2020-02-18 12:26:00
# ...                    ...
# 136355 2020-04-13 19:27:00
# 136358 2020-02-24 18:15:00
# 136359 2020-06-10 18:27:00
# 136361 2020-03-30 08:31:00
# 136541 2020-09-15 14:47:00
#
# [9585 rows x 18 columns]

# %%
animals.loc[animals['Year'] >= 2020, 'Animal ID'].nunique()
# Out:
# 21700

# %%
animals[animals['Year'] == 2020].shape
# Out:
# (9585, 18)

# %%
#df.loc[rows,columns]
#df.iloc[row,columns]

#df.loc[row selector, column selector]

# %%
# Let's explore an interesting property of boolean columns...
# Find out the total sum of animals taken in during or after 2020

# %% [markdown]
# But this only gives us True/False outputs... what if we want to really filter?

# %% [markdown]
# ## `.loc`

# %% [markdown]
# We can locate and segment down to only rows where some condition is true using `.loc`. This takes in a condition, and only outputs the rows where that condition is True!
#
# > **Note:** locate (`.loc`) uses square brackets, not parentheses! Often, square brackets denote location-focused actions, like this one.
#
# Let's try this first with the condition we just built, and locate all animals taken in during or after 2020.

# %%
# Create a subset dataframe of animals taken in during or after 2020
new_animals_animal_type = animals.loc[animals['Year'] >= 2020, 'Animal Type']
new_animals_animal_type
# Out:
# 7         Cat
# 9         Cat
# 22        Cat
# 24        Dog
# 26        Dog
#          ...
# 136759    Dog
# 136760    Dog
# 136761    Dog
# 136762    Dog
# 136763    Cat
# Name: Animal Type, Length: 23270, dtype: object

# %%
animals.loc[animals['Year'] >= 2020][['Name', 'Animal ID', 'Animal Type']]
# Out:
#             Name Animal ID Animal Type
# 7          *Ella   A844350         Cat
# 9            NaN   A818975         Cat
# 22           NaN   A831808         Cat
# 24           NaN   A836850         Dog
# 26          Baby   A815227         Dog
# ...          ...       ...         ...
# 136759      Coco   A852221         Dog
# 136760     *Jack   A851977         Dog
# 136761     Sonic   A852127         Dog
# 136762     Queen   A852194         Dog
# 136763  T'Challa   A851755         Cat
#
# [23270 rows x 3 columns]

# %%
new_animals = animals.loc[animals['Year'] >= 2020]

# %%
# Sanity check
new_animals
# Out:
#        Animal ID      Name            DateTime  Year  \
# 7        A844350     *Ella 2021-10-15 11:40:00  2021
# 9        A818975       NaN 2020-06-18 14:53:00  2020
# 22       A831808       NaN 2021-04-02 11:16:00  2021
# 24       A836850       NaN 2021-06-15 12:37:00  2021
# 26       A815227      Baby 2020-03-12 13:52:00  2020
# ...          ...       ...                 ...   ...
# 136759   A852221      Coco 2022-02-28 11:05:00  2022
# 136760   A851977     *Jack 2022-02-22 13:34:00  2022
# 136761   A852127     Sonic 2022-02-25 13:05:00  2022
# 136762   A852194     Queen 2022-02-27 13:44:00  2022
# 136763   A851755  T'Challa 2022-02-28 11:25:00  2022
#
#                                        Found Location      Intake Type  \
# 7       2112 East William Cannon Drive in Austin (TX)            Stray
# 9               Braker Lane And Metric in Travis (TX)            Stray
# 22                                        Austin (TX)  Owner Surrender
# 24                 6111 Softwood Drive in Austin (TX)    Public Assist
# 26                   12305 Zeller Lane in Austin (TX)            Stray
# ...                                               ...              ...
# 136759                      45 And 183 in Travis (TX)            Stray
# 136760           1200 Montopolis Drive in Austin (TX)            Stray
# 136761         7601 Daffan Ln Unit 424 in Austin (TX)            Stray
# 136762               8071 N Lamar Blvd in Austin (TX)            Stray
# 136763                                   Houston (TX)    Public Assist
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 7                Normal         Cat   Intact Female        6 months
# 9                Normal         Cat     Intact Male         4 weeks
# 22               Normal         Cat   Intact Female         1 month
# 24             Pregnant         Dog   Intact Female         4 years
# 26               Normal         Dog   Intact Female         1 month
# ...                 ...         ...             ...             ...
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
# 136763           Normal         Cat   Neutered Male         4 years
#
#                                 Breed         Color      MonthYear  \
# 7                  Domestic Shorthair   Brown Tabby            NaN
# 9                  Domestic Shorthair   Cream Tabby            NaN
# 22             Domestic Shorthair Mix        Tortie            NaN
# 24                           Pit Bull    Blue/White            NaN
# 26                    Norfolk Terrier   Brown/Cream            NaN
# ...                               ...           ...            ...
# 136759                 Great Pyrenees         White            NaN
# 136760  Chihuahua Shorthair/Dachshund   Black/White            NaN
# 136761                   Pit Bull Mix  White/Yellow            NaN
# 136762                     Cane Corso    Blue Cream            NaN
# 136763             Domestic Shorthair         Black  February 2022
#
#                       type                Type  Year Plus 5  Day of Week  \
# 7                 StrayCat            StrayCat       2026.0          3.0
# 9                 StrayCat            StrayCat       2025.0          3.0
# 22      Owner SurrenderCat  Owner SurrenderCat       2026.0          3.0
# 24        Public AssistDog    Public AssistDog       2026.0          3.0
# 26                StrayDog            StrayDog       2025.0          3.0
# ...                    ...                 ...          ...          ...
# 136759            StrayDog            StrayDog       2027.0          3.0
# 136760            StrayDog            StrayDog       2027.0          3.0
# 136761            StrayDog            StrayDog       2027.0          3.0
# 136762            StrayDog            StrayDog       2027.0          3.0
# 136763    Public AssistCat    Public AssistCat          NaN          NaN
#
#                Intake Year
# 7      2021-10-15 11:40:00
# 9      2020-06-18 14:53:00
# 22     2021-04-02 11:16:00
# 24     2021-06-15 12:37:00
# 26     2020-03-12 13:52:00
# ...                    ...
# 136759 2022-02-28 11:05:00
# 136760 2022-02-22 13:34:00
# 136761 2022-02-25 13:05:00
# 136762 2022-02-27 13:44:00
# 136763 2022-02-28 11:25:00
#
# [23270 rows x 18 columns]

# %% [markdown]
# We can return only certain columns when we do this, by adding an argument after the condition:

# %%
# Let's return just the 'Animal ID', 'DateTime' and 'Type' columns

# %% [markdown]
# What if I want to segment using multiple conditions? Use `&` for "and" and `|` for "or" - and use parentheses around individual conditions!

# %%
animals.loc[(animals['Animal Type'] == 'Stray') & (animals['Year'] >= 2020)]
# Out:
# Empty DataFrame
# Columns: [Animal ID, Name, DateTime, Year, Found Location, Intake Type, Intake Condition, Animal Type, Sex upon Intake, Age upon Intake, Breed, Color, MonthYear, type, Type, Year Plus 5, Day of Week, Intake Year]
# Index: []

# %%
# Find all the Stray Cats taken in during or after 2020
animals.loc(animals['Year'] >= 2020][['Animal Type','Intake Type']]
# Out:
#        Animal Type      Intake Type
# 7              Cat            Stray
# 9              Cat            Stray
# 22             Cat  Owner Surrender
# 24             Dog    Public Assist
# 26             Dog            Stray
# ...            ...              ...
# 136759         Dog            Stray
# 136760         Dog            Stray
# 136761         Dog            Stray
# 136762         Dog            Stray
# 136763         Cat    Public Assist
#
# [23270 rows x 2 columns]

# %% [markdown]
# ### Your turn!

# %% [markdown]
# #### Exercise 1
#
# You need to find dogs that need extra attention - How would you find all dogs where the intake condition is NOT normal?

# %%
animals.loc[animals['Intake Condition'] != 'Normal']
# Out:
#        Animal ID          Name            DateTime  Year  \
# 3        A665644           NaN 2013-10-21 07:59:00  2013
# 10       A774147           NaN 2018-06-11 07:45:00  2018
# 16       A743114           NaN 2017-02-04 10:10:00  2017
# 24       A836850           NaN 2021-06-15 12:37:00  2021
# 38       A794334         Pearl 2019-09-02 11:52:00  2019
# ...          ...           ...                 ...   ...
# 136728   A852084  *Maple Syrup 2022-02-24 13:29:00  2022
# 136730   A852207           NaN 2022-02-28 07:16:00  2022
# 136733   A852038       *Minkus 2022-02-23 15:01:00  2022
# 136742   A850725         Monty 2022-01-30 14:32:00  2022
# 136754   A852234           NaN 2022-02-28 12:33:00  2022
#
#                             Found Location      Intake Type Intake Condition  \
# 3                              Austin (TX)            Stray             Sick
# 10           6600 Elm Creek in Austin (TX)            Stray          Injured
# 16            208 Beaver St in Austin (TX)            Stray          Injured
# 24      6111 Softwood Drive in Austin (TX)    Public Assist         Pregnant
# 38                    Outside Jurisdiction  Owner Surrender             Sick
# ...                                    ...              ...              ...
# 136728     6911 Bennett Ave in Austin (TX)            Stray          Injured
# 136730  4434 Frontier Trail in Austin (TX)  Owner Surrender             Sick
# 136733        3403 E 5Th St in Austin (TX)            Stray          Injured
# 136742     14100 Thermal Dr in Austin (TX)            Stray          Injured
# 136754      305 E Lola Lane in Austin (TX)            Stray          Injured
#
#        Animal Type Sex upon Intake Age upon Intake                   Breed  \
# 3              Cat   Intact Female         4 weeks  Domestic Shorthair Mix
# 10             Cat   Intact Female         4 weeks  Domestic Shorthair Mix
# 16             Cat   Intact Female         2 years  Domestic Shorthair Mix
# 24             Dog   Intact Female         4 years                Pit Bull
# 38             Dog   Spayed Female         3 years               Boxer Mix
# ...            ...             ...             ...                     ...
# 136728         Dog   Intact Female        2 months  Labrador Retriever Mix
# 136730         Cat     Intact Male         2 weeks      Domestic Shorthair
# 136733         Cat   Neutered Male       11 months      Domestic Shorthair
# 136742         Dog     Intact Male         2 years      Labrador Retriever
# 136754         Cat   Intact Female         2 years      Domestic Shorthair
#
#               Color MonthYear                type                Type  \
# 3            Calico       NaN            StrayCat            StrayCat
# 10      Black/White       NaN            StrayCat            StrayCat
# 16      Black/White       NaN            StrayCat            StrayCat
# 24       Blue/White       NaN    Public AssistDog    Public AssistDog
# 38            White       NaN  Owner SurrenderDog  Owner SurrenderDog
# ...             ...       ...                 ...                 ...
# 136728  Black/White       NaN            StrayDog            StrayDog
# 136730  Brown Tabby       NaN  Owner SurrenderCat  Owner SurrenderCat
# 136733        Black       NaN            StrayCat            StrayCat
# 136742  Black/White       NaN            StrayDog            StrayDog
# 136754       Calico       NaN            StrayCat            StrayCat
#
#         Year Plus 5  Day of Week         Intake Year
# 3            2018.0          3.0 2013-10-21 07:59:00
# 10           2023.0          3.0 2018-06-11 07:45:00
# 16           2022.0          3.0 2017-02-04 10:10:00
# 24           2026.0          3.0 2021-06-15 12:37:00
# 38           2024.0          3.0 2019-09-02 11:52:00
# ...             ...          ...                 ...
# 136728       2027.0          3.0 2022-02-24 13:29:00
# 136730       2027.0          3.0 2022-02-28 07:16:00
# 136733       2027.0          3.0 2022-02-23 15:01:00
# 136742       2027.0          3.0 2022-01-30 14:32:00
# 136754       2027.0          3.0 2022-02-28 12:33:00
#
# [18896 rows x 18 columns]

# %% [markdown]
# #### Exercise 2
#
# You need to find animals that might need to be fixed - How would you find all animals that are either Intact Male or Intact Female?

# %%
animals.loc[(animals['Sex upon Intake'] == 'Intact Female') | (animals['Sex upon Intake'] == 'Intact Male')]
# Out:
#        Animal ID     Name            DateTime  Year  \
# 2        A724273  Runster 2016-04-14 18:43:00  2016
# 3        A665644      NaN 2013-10-21 07:59:00  2013
# 7        A844350    *Ella 2021-10-15 11:40:00  2021
# 8        A708452   Mumble 2015-07-30 14:37:00  2015
# 9        A818975      NaN 2020-06-18 14:53:00  2020
# ...          ...      ...                 ...   ...
# 136758   A852238  A852238 2022-02-28 14:02:00  2022
# 136759   A852221     Coco 2022-02-28 11:05:00  2022
# 136760   A851977    *Jack 2022-02-22 13:34:00  2022
# 136761   A852127    Sonic 2022-02-25 13:05:00  2022
# 136762   A852194    Queen 2022-02-27 13:44:00  2022
#
#                                        Found Location    Intake Type  \
# 2                  2818 Palomino Trail in Austin (TX)          Stray
# 3                                         Austin (TX)          Stray
# 7       2112 East William Cannon Drive in Austin (TX)          Stray
# 8                                         Austin (TX)  Public Assist
# 9               Braker Lane And Metric in Travis (TX)          Stray
# ...                                               ...            ...
# 136758     Cameron And Crosspark Drive in Austin (TX)          Stray
# 136759                      45 And 183 in Travis (TX)          Stray
# 136760           1200 Montopolis Drive in Austin (TX)          Stray
# 136761         7601 Daffan Ln Unit 424 in Austin (TX)          Stray
# 136762               8071 N Lamar Blvd in Austin (TX)          Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 2                Normal         Dog     Intact Male       11 months
# 3                  Sick         Cat   Intact Female         4 weeks
# 7                Normal         Cat   Intact Female        6 months
# 8                Normal         Dog     Intact Male         2 years
# 9                Normal         Cat     Intact Male         4 weeks
# ...                 ...         ...             ...             ...
# 136758           Normal         Dog   Intact Female        6 months
# 136759           Normal         Dog     Intact Male         3 years
# 136760           Normal         Dog     Intact Male         2 years
# 136761           Normal         Dog     Intact Male         2 years
# 136762           Normal         Dog   Intact Female        4 months
#
#                                 Breed         Color MonthYear  \
# 2                         Basenji Mix   Sable/White       NaN
# 3              Domestic Shorthair Mix        Calico       NaN
# 7                  Domestic Shorthair   Brown Tabby       NaN
# 8              Labrador Retriever Mix   Black/White       NaN
# 9                  Domestic Shorthair   Cream Tabby       NaN
# ...                               ...           ...       ...
# 136758         Labrador Retriever Mix   Black/White       NaN
# 136759                 Great Pyrenees         White       NaN
# 136760  Chihuahua Shorthair/Dachshund   Black/White       NaN
# 136761                   Pit Bull Mix  White/Yellow       NaN
# 136762                     Cane Corso    Blue Cream       NaN
#
#                     type              Type  Year Plus 5  Day of Week  \
# 2               StrayDog          StrayDog       2021.0          3.0
# 3               StrayCat          StrayCat       2018.0          3.0
# 7               StrayCat          StrayCat       2026.0          3.0
# 8       Public AssistDog  Public AssistDog       2020.0          3.0
# 9               StrayCat          StrayCat       2025.0          3.0
# ...                  ...               ...          ...          ...
# 136758          StrayDog          StrayDog       2027.0          3.0
# 136759          StrayDog          StrayDog       2027.0          3.0
# 136760          StrayDog          StrayDog       2027.0          3.0
# 136761          StrayDog          StrayDog       2027.0          3.0
# 136762          StrayDog          StrayDog       2027.0          3.0
#
#                Intake Year
# 2      2016-04-14 18:43:00
# 3      2013-10-21 07:59:00
# 7      2021-10-15 11:40:00
# 8      2015-07-30 14:37:00
# 9      2020-06-18 14:53:00
# ...                    ...
# 136758 2022-02-28 14:02:00
# 136759 2022-02-28 11:05:00
# 136760 2022-02-22 13:34:00
# 136761 2022-02-25 13:05:00
# 136762 2022-02-27 13:44:00
#
# [87649 rows x 18 columns]

# %% [markdown]
# ## `.iloc`

# %% [markdown]
# `.iloc` is used for integer-location based indexing, aka locate by number. It can take in lists of numbers, python slices, or specific numbers - but sometimes it can be a bit tricky!

# %%
# Find the first 3 rows
animals.iloc[10:60,15:18]
# Out:
#     Year Plus 5  Day of Week         Intake Year
# 10       2023.0          3.0 2018-06-11 07:45:00
# 11       2021.0          3.0 2016-08-08 17:52:00
# 12       2022.0          3.0 2017-10-11 15:46:00
# 13       2020.0          3.0 2015-07-11 18:19:00
# 14       2020.0          3.0 2015-02-04 12:58:00
# 15       2024.0          3.0 2019-03-06 14:31:00
# 16       2022.0          3.0 2017-02-04 10:10:00
# 17       2018.0          3.0 2013-11-10 17:19:00
# 18       2023.0          3.0 2018-11-07 15:53:00
# 19       2020.0          3.0 2015-07-15 17:43:00
# 20       2021.0          3.0 2016-10-08 11:53:00
# 21       2020.0          3.0 2015-03-04 11:22:00
# 22       2026.0          3.0 2021-04-02 11:16:00
# 23       2020.0          3.0 2015-09-06 14:21:00
# 24       2026.0          3.0 2021-06-15 12:37:00
# 25       2024.0          3.0 2019-07-29 17:19:00
# 26       2025.0          3.0 2020-03-12 13:52:00
# 27       2024.0          3.0 2019-12-25 00:05:00
# 28       2023.0          3.0 2018-04-09 19:03:00
# 29       2020.0          3.0 2015-07-20 18:13:00
# 30       2019.0          3.0 2014-06-25 16:27:00
# 31       2026.0          3.0 2021-03-19 15:40:00
# 32       2022.0          3.0 2017-05-15 09:50:00
# 33       2021.0          3.0 2016-03-24 16:39:00
# 34       2024.0          3.0 2019-09-05 12:00:00
# 35       2020.0          3.0 2015-02-12 11:57:00
# 36       2022.0          3.0 2017-10-09 22:39:00
# 37       2018.0          3.0 2013-11-08 15:24:00
# 38       2024.0          3.0 2019-09-02 11:52:00
# 39       2020.0          3.0 2015-06-29 17:04:00
# 40       2021.0          3.0 2016-08-14 15:02:00
# 41       2024.0          3.0 2019-02-23 11:22:00
# 42       2022.0          3.0 2017-05-14 14:19:00
# 43       2021.0          3.0 2016-05-26 14:01:00
# 44       2025.0          3.0 2020-08-10 14:10:00
# 45       2023.0          3.0 2018-04-10 16:46:00
# 46       2020.0          3.0 2015-05-05 07:29:00
# 47       2025.0          3.0 2020-01-18 14:14:00
# 48       2020.0          3.0 2015-12-07 09:11:00
# 49       2021.0          3.0 2016-04-16 13:36:00
# 50       2020.0          3.0 2015-05-16 18:38:00
# 51       2022.0          3.0 2017-10-11 11:48:00
# 52       2020.0          3.0 2015-05-19 13:23:00
# 53       2022.0          3.0 2017-03-13 12:50:00
# 54       2022.0          3.0 2017-04-25 12:02:00
# 55       2024.0          3.0 2019-01-07 13:41:00
# 56       2021.0          3.0 2016-10-11 16:43:00
# 57       2022.0          3.0 2017-07-29 11:49:00
# 58       2020.0          3.0 2015-03-30 15:23:00
# 59       2024.0          3.0 2019-12-21 11:09:00

# %%
animals.iloc[0:3,:]
# Out:
#   Animal ID     Name            DateTime  Year  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2019
# 1   A706918    Belle 2015-07-05 12:59:00  2015
# 2   A724273  Runster 2016-04-14 18:43:00  2016
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
# 2         Dog     Intact Male       11 months               Basenji Mix
#
#          Color MonthYear      type      Type  Year Plus 5  Day of Week  \
# 0     Tricolor       NaN  StrayDog  StrayDog       2024.0          3.0
# 1  White/Liver       NaN  StrayDog  StrayDog       2020.0          3.0
# 2  Sable/White       NaN  StrayDog  StrayDog       2021.0          3.0
#
#           Intake Year
# 0 2019-01-03 16:19:00
# 1 2015-07-05 12:59:00
# 2 2016-04-14 18:43:00

# %%
# Can look exactly where the 0 index is
new_animals.iloc[0,:]
# Out:
# Animal ID                                                 A844350
# Name                                                        *Ella
# DateTime                                      2021-10-15 11:40:00
# Year                                                         2021
# Found Location      2112 East William Cannon Drive in Austin (TX)
# Intake Type                                                 Stray
# Intake Condition                                           Normal
# Animal Type                                                   Cat
# Sex upon Intake                                     Intact Female
# Age upon Intake                                          6 months
# Breed                                          Domestic Shorthair
# Color                                                 Brown Tabby
# MonthYear                                                     NaN
# type                                                     StrayCat
# Type                                                     StrayCat
# Year Plus 5                                                  2026
# Day of Week                                                     3
# Intake Year                                   2021-10-15 11:40:00
# Name: 7, dtype: object

# %%
animals.head(3)
# Out:
#   Animal ID     Name            DateTime  Year  \
# 0   A786884   *Brock 2019-01-03 16:19:00  2019
# 1   A706918    Belle 2015-07-05 12:59:00  2015
# 2   A724273  Runster 2016-04-14 18:43:00  2016
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake                     Breed  \
# 0         Dog   Neutered Male         2 years                Beagle Mix
# 1         Dog   Spayed Female         8 years  English Springer Spaniel
# 2         Dog     Intact Male       11 months               Basenji Mix
#
#          Color MonthYear      type      Type  Year Plus 5  Day of Week  \
# 0     Tricolor       NaN  StrayDog  StrayDog       2024.0          3.0
# 1  White/Liver       NaN  StrayDog  StrayDog       2020.0          3.0
# 2  Sable/White       NaN  StrayDog  StrayDog       2021.0          3.0
#
#           Intake Year
# 0 2019-01-03 16:19:00
# 1 2015-07-05 12:59:00
# 2 2016-04-14 18:43:00

# %%
animals.head(1)
# Out:
#   Animal ID    Name            DateTime  Year  \
# 0   A786884  *Brock 2019-01-03 16:19:00  2019
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake       Breed     Color MonthYear  \
# 0         Dog   Neutered Male         2 years  Beagle Mix  Tricolor       NaN
#
#        type      Type  Year Plus 5  Day of Week         Intake Year
# 0  StrayDog  StrayDog       2024.0          3.0 2019-01-03 16:19:00

# %%
new_animals.head(1)
# Out:
#   Animal ID   Name            DateTime  Year  \
# 7   A844350  *Ella 2021-10-15 11:40:00  2021
#
#                                   Found Location Intake Type Intake Condition  \
# 7  2112 East William Cannon Drive in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake               Breed  \
# 7         Cat   Intact Female        6 months  Domestic Shorthair
#
#          Color MonthYear      type      Type  Year Plus 5  Day of Week  \
# 7  Brown Tabby       NaN  StrayCat  StrayCat       2026.0          3.0
#
#           Intake Year
# 7 2021-10-15 11:40:00

# %% [markdown]
# # Series Methods

# %% [markdown]
# ## `.value_counts()`

# %% [markdown]
# How many different values does the Animal Type column have? What about Breed?

# %%
# Check the value counts for Animal Type
animals['Animal Type'].value_counts()
# Out:
# Dog          77098
# Cat          51753
# Other         7253
# Bird           636
# Livestock       24
# Name: Animal Type, dtype: int64

# %%
animals['Year'].value_counts()
# Out:
# 2019    19727
# 2015    18712
# 2014    18656
# 2016    17675
# 2017    17563
# 2018    16979
# 2021    12042
# 2020     9585
# 2013     4182
# 2022     1643
# Name: Year, dtype: int64

# %%
# Now check Breed
animals['Breed'].value_counts()
# Out:
# Domestic Shorthair Mix               32034
# Domestic Shorthair                   10441
# Pit Bull Mix                          8913
# Labrador Retriever Mix                7370
# Chihuahua Shorthair Mix               6486
#                                      ...
# Black                                    1
# Smooth Fox Terrier/French Bulldog        1
# Australian Shepherd/Beagle               1
# Whippet/Whippet                          1
# Whimbrel Mix                             1
# Name: Breed, Length: 2734, dtype: int64

# %% [markdown]
# Sometimes, this is more useful than others... but, can check the percentage of the total, which might be more useful!

# %%
# Use the normalize argument to view as percentages
animals.loc[animals['Animal Type'] == 'Cat']['Breed'].value_counts(normalize = True)
# Out:
# Domestic Shorthair Mix             0.618979
# Domestic Shorthair                 0.201747
# Domestic Medium Hair Mix           0.062122
# Domestic Longhair Mix              0.030530
# Siamese Mix                        0.025989
#                                      ...
# Ocicat Mix                         0.000019
# Siamese/Angora                     0.000019
# Turkish Angora                     0.000019
# American Curl Shorthair/Siamese    0.000019
# Balinese                           0.000019
# Name: Breed, Length: 103, dtype: float64

# %%
df['target'].value_counts(normalize = True)
# Out:
# 1    0.544554
# 0    0.455446
# Name: target, dtype: float64

# %% [markdown]
# ## `.sort_values()`
#
# As you can imagine, this works differently whether you're using it on a numeric or non-numeric column

# %%
# Let's sort the year column
animals['Year'].sort_values(ascending = False)
# Out:
# 136763    2022
# 135566    2022
# 135553    2022
# 135554    2022
# 135555    2022
#           ...
# 118202    2013
# 82804     2013
# 74446     2013
# 31112     2013
# 13061     2013
# Name: Year, Length: 136764, dtype: int64

# %%
animals.sort_values(by = 'Year', ascending = False)
# Out:
#        Animal ID          Name            DateTime  Year  \
# 136763   A851755      T'Challa 2022-02-28 11:25:00  2022
# 135598   A850355          *Sox 2022-01-22 13:24:00  2022
# 135600   A850150  French Toast 2022-01-19 11:59:00  2022
# 135601   A850150  French Toast 2022-01-26 12:42:00  2022
# 135603   A850485         Rocco 2022-01-25 12:50:00  2022
# ...          ...           ...                 ...   ...
# 114540   A668192           NaN 2013-11-29 12:47:00  2013
# 7568     A666609        Peewee 2013-11-04 13:51:00  2013
# 6328     A667157         Jason 2013-11-13 14:52:00  2013
# 114531   A666725           NaN 2013-11-06 12:55:00  2013
# 96175    A665567          Baby 2013-10-19 12:57:00  2013
#
#                                Found Location      Intake Type  \
# 136763                           Houston (TX)    Public Assist
# 135598       7517 Cameron Road in Austin (TX)            Stray
# 135600                             Manor (TX)  Owner Surrender
# 135601                            Austin (TX)  Owner Surrender
# 135603      7201 Levander Loop in Austin (TX)            Stray
# ...                                       ...              ...
# 114540  Long Vista And Bratton in Austin (TX)            Stray
# 7568                              Austin (TX)  Owner Surrender
# 6328                        Pflugerville (TX)  Owner Surrender
# 114531        13021 Dessau  Rd in Austin (TX)            Stray
# 96175       7201 Levander Loop in Austin (TX)            Stray
#
#        Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 136763           Normal         Cat   Neutered Male         4 years
# 135598           Normal         Dog     Intact Male          1 year
# 135600           Normal         Dog     Intact Male        5 months
# 135601           Normal         Dog   Neutered Male        5 months
# 135603           Normal         Dog     Intact Male        8 months
# ...                 ...         ...             ...             ...
# 114540           Normal         Dog   Intact Female         2 years
# 7568             Normal         Cat   Neutered Male         6 years
# 6328             Normal         Cat     Intact Male        3 months
# 114531           Normal         Dog     Intact Male        2 months
# 96175            Normal         Dog   Neutered Male         2 years
#
#                            Breed              Color      MonthYear  \
# 136763        Domestic Shorthair              Black  February 2022
# 135598                  Pit Bull          Tan/White            NaN
# 135600    Labrador Retriever Mix          White/Tan            NaN
# 135601    Labrador Retriever Mix          White/Tan            NaN
# 135603   Australian Shepherd Mix        Black/Brown            NaN
# ...                          ...                ...            ...
# 114540          Picardy Sheepdog          Tan/White            NaN
# 7568      Domestic Shorthair Mix               Blue            NaN
# 6328    Domestic Medium Hair Mix  Cream Tabby/White            NaN
# 114531   Pointer/Anatol Shepherd        White/Brown            NaN
# 96175    Chihuahua Shorthair Mix    Chocolate/White            NaN
#
#                       type                Type  Year Plus 5  Day of Week  \
# 136763    Public AssistCat    Public AssistCat          NaN          NaN
# 135598            StrayDog            StrayDog       2027.0          3.0
# 135600  Owner SurrenderDog  Owner SurrenderDog       2027.0          3.0
# 135601  Owner SurrenderDog  Owner SurrenderDog       2027.0          3.0
# 135603            StrayDog            StrayDog       2027.0          3.0
# ...                    ...                 ...          ...          ...
# 114540            StrayDog            StrayDog       2018.0          3.0
# 7568    Owner SurrenderCat  Owner SurrenderCat       2018.0          3.0
# 6328    Owner SurrenderCat  Owner SurrenderCat       2018.0          3.0
# 114531            StrayDog            StrayDog       2018.0          3.0
# 96175             StrayDog            StrayDog       2018.0          3.0
#
#                Intake Year
# 136763 2022-02-28 11:25:00
# 135598 2022-01-22 13:24:00
# 135600 2022-01-19 11:59:00
# 135601 2022-01-26 12:42:00
# 135603 2022-01-25 12:50:00
# ...                    ...
# 114540 2013-11-29 12:47:00
# 7568   2013-11-04 13:51:00
# 6328   2013-11-13 14:52:00
# 114531 2013-11-06 12:55:00
# 96175  2013-10-19 12:57:00
#
# [136764 rows x 18 columns]

# %%
# Now, sort the Animal Type col
animals.sort_values(by = 'Animal Type', ascending = False)
# Out:
#       Animal ID             Name            DateTime  Year  \
# 84730   A721703              NaN 2016-03-02 15:25:00  2016
# 19665   A814692              NaN 2020-03-03 22:54:00  2020
# 8211    A678622              NaN 2014-05-10 18:55:00  2014
# 77281   A840507  *Siouxsie Sioux 2021-08-09 16:03:00  2021
# 8217    A749933              NaN 2017-05-21 14:46:00  2017
# ...         ...              ...                 ...   ...
# 75600   A757067              NaN 2017-08-29 14:56:00  2017
# 68935   A839271              NaN 2021-07-19 15:05:00  2021
# 5478    A770409              NaN 2018-04-19 13:59:00  2018
# 66611   A715668              NaN 2015-11-07 17:14:00  2015
# 6992    A779661              NaN 2018-09-04 13:02:00  2018
#
#                                    Found Location      Intake Type  \
# 84730          5901 Southwest Pkwy in Austin (TX)         Wildlife
# 19665  3351 Killingsworth Ln in Pflugerville (TX)         Wildlife
# 8211           Riverside And Grove in Austin (TX)            Stray
# 77281                                 Austin (TX)  Owner Surrender
# 8217           11500 Jollyville Rd in Austin (TX)         Wildlife
# ...                                           ...              ...
# 75600           7201 Levander Loop in Austin (TX)         Wildlife
# 68935   Highway 183 And Smith Road in Austin (TX)            Stray
# 5478                 8800 S 1St St in Austin (TX)         Wildlife
# 66611              830 Bastrop Hwy in Austin (TX)         Wildlife
# 6992               107 E Brenham St in Manor (TX)    Public Assist
#
#       Intake Condition Animal Type Sex upon Intake Age upon Intake  \
# 84730           Normal       Other         Unknown          1 year
# 19665          Injured       Other         Unknown          1 year
# 8211           Injured       Other         Unknown          1 year
# 77281           Normal       Other   Intact Female        5 months
# 8217           Injured       Other         Unknown          1 year
# ...                ...         ...             ...             ...
# 75600          Injured        Bird         Unknown         2 years
# 68935           Normal        Bird   Intact Female          1 year
# 5478           Injured        Bird         Unknown         2 years
# 66611          Injured        Bird         Unknown         2 years
# 6992            Normal        Bird     Intact Male          1 year
#
#                Breed        Color MonthYear                  type  \
# 84730        Bat Mix        Brown       NaN         WildlifeOther
# 19665            Bat        Brown       NaN         WildlifeOther
# 8211   Rabbit Sh Mix   Gray/White       NaN            StrayOther
# 77281          Mouse  White/Black       NaN  Owner SurrenderOther
# 8217             Fox  Brown/White       NaN         WildlifeOther
# ...              ...          ...       ...                   ...
# 75600    Grackle Mix        Black       NaN          WildlifeBird
# 68935        Chicken        Brown       NaN             StrayBird
# 5478     Vulture Mix        Brown       NaN          WildlifeBird
# 66611     Pigeon Mix         Gray       NaN          WildlifeBird
# 6992         Chicken    Red/Black       NaN     Public AssistBird
#
#                        Type  Year Plus 5  Day of Week         Intake Year
# 84730         WildlifeOther       2021.0          3.0 2016-03-02 15:25:00
# 19665         WildlifeOther       2025.0          3.0 2020-03-03 22:54:00
# 8211             StrayOther       2019.0          3.0 2014-05-10 18:55:00
# 77281  Owner SurrenderOther       2026.0          3.0 2021-08-09 16:03:00
# 8217          WildlifeOther       2022.0          3.0 2017-05-21 14:46:00
# ...                     ...          ...          ...                 ...
# 75600          WildlifeBird       2022.0          3.0 2017-08-29 14:56:00
# 68935             StrayBird       2026.0          3.0 2021-07-19 15:05:00
# 5478           WildlifeBird       2023.0          3.0 2018-04-19 13:59:00
# 66611          WildlifeBird       2020.0          3.0 2015-11-07 17:14:00
# 6992      Public AssistBird       2023.0          3.0 2018-09-04 13:02:00
#
# [136764 rows x 18 columns]

# %% [markdown]
# # Extra Credit: Find a .csv file online and experiment with it.

# %% [markdown]
# Head to [dataportals.org](https://dataportals.org) to find a .csv file.
